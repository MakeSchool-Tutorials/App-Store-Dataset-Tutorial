# %% [markdown]
# # <center>Final Answer Notebook: Exploratory Data Analysis</center>

# %% [markdown]
# ### Welcome to the answers for the Exploratory Data Analysis tutorial.
#
# In this tutorial, we'll quickly explore a simple dataset designed to cultivate your interest in extracting unique insights from data.
#
# **Dataset**: [App Store Mobile Apps](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps/version/2) dataset from Kaggle.
#
# ### Before moving any further, ensure you have the following prerequisites met:
# - Anaconda Navigator installed and running successfully.
# - Jupyter works successfully.
# - Python 3.6+ installed and working.
# - Tutorial repo was forked and set up successfully.

# %%
# Pandas is an accessory library for basic data manipulation and analysis.
import pandas as pd

# NumPy is a numerical library for manipulating and utilizing higher-dimensional arrays for advanced computation.
import numpy as np

# MatPlotLib is a plotting library for simple visual data representation.
import matplotlib.pyplot as plt
% matplotlib inline

# SeaBorn is a more advanced library for statistical and spatial data visualization.
import seaborn as sns

# %%
# Here, we run some basic setup for some visualization work in SeaBorn and MatPlotLib – to be explained later!

sns.set(style="white", context="notebook", palette="deep")

COLOR_COLUMNS = ["#66C2FF", "#5CD6D6", "#00CC99", "#85E085", "#FFD966", "#FFB366", "#FFB3B3", "#DAB3FF", "#C2C2D6"]
sns.set_palette(palette=COLOR_COLUMNS, n_colors=4)

# %% [markdown]
# ## Setting up our DataFrame

# %% [markdown]
# Here, we'll grab our file (AppleStore.csv) and call it as a <strong>DataFrame</strong> – a Pandas-specific array-like object that's very useful for visually representing and interpreting data in a programmatic manner.

# %%
# NOTE: Must be in the /tutorials/ directory. (Not the /datasets/ directory.)

FILEPATH = "../datasets/AppleStore.csv"

df = pd.read_csv(FILEPATH, index_col="Unnamed: 0")
df
# Out:
#                id                                         track_name  \
# 1       281656475                                    PAC-MAN Premium
# 2       281796108                          Evernote - stay organized
# 3       281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 4       282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 5       282935706                                              Bible
# 6       283619399                                   Shanghai Mahjong
# 7       283646709             PayPal - Send and request money safely
# 8       284035177                            Pandora - Music & Radio
# 9       284666222                        PCalc - The Best Calculator
# 10      284736660                                        Ms. PAC-MAN
# 11      284791396                          Solitaire by MobilityWare
# 12      284815117                                   SCRABBLE Premium
# 13      284815942               Google – Search made just for mobile
# ...

# %% [markdown]
# ### One important thing to check for in any dataset is the occurrence of NULL VALUES.
#
# <strong>NULL VALUES</strong> are values that are empty or that do not exist. Usually this occurs from empty cells in Excel sheets or failing to preprocess datasets effectively to check where no recorded data exists.

# %%
df.isnull()
# Out:
#           id  track_name  size_bytes  currency  price  rating_count_tot  \
# 1      False       False       False     False  False             False
# 2      False       False       False     False  False             False
# 3      False       False       False     False  False             False
# 4      False       False       False     False  False             False
# 5      False       False       False     False  False             False
# 6      False       False       False     False  False             False
# 7      False       False       False     False  False             False
# 8      False       False       False     False  False             False
# 9      False       False       False     False  False             False
# 10     False       False       False     False  False             False
# 11     False       False       False     False  False             False
# 12     False       False       False     False  False             False
# ...

# %%
df.isnull().sum()
# Out:
# id                  0
# track_name          0
# size_bytes          0
# currency            0
# price               0
# rating_count_tot    0
# rating_count_ver    0
# user_rating         0
# user_rating_ver     0
# ver                 0
# cont_rating         0
# prime_genre         0
# sup_devices.num     0
# ipadSc_urls.num     0
# lang.num            0
# vpp_lic             0
# dtype: int64

# %% [markdown]
# ### Now that we know the data is relatively clean, let's take a look at the actual data it contains!

# %%
df.describe()
# Out:
#                  id    size_bytes        price  rating_count_tot  \
# count  7.197000e+03  7.197000e+03  7197.000000      7.197000e+03
# mean   8.631310e+08  1.991345e+08     1.726218      1.289291e+04
# std    2.712368e+08  3.592069e+08     5.833006      7.573941e+04
# min    2.816565e+08  5.898240e+05     0.000000      0.000000e+00
# 25%    6.000937e+08  4.692275e+07     0.000000      2.800000e+01
# 50%    9.781482e+08  9.715302e+07     0.000000      3.000000e+02
# 75%    1.082310e+09  1.819249e+08     1.990000      2.793000e+03
# max    1.188376e+09  4.025970e+09   299.990000      2.974676e+06
#
#        rating_count_ver  user_rating  user_rating_ver  sup_devices.num  \
# count       7197.000000  7197.000000      7197.000000      7197.000000
# mean         460.373906     3.526956         3.253578        37.361817
# std         3920.455183     1.517948         1.809363         3.737715
# min            0.000000     0.000000         0.000000         9.000000
# ...

# %% [markdown]
# The <i>.describe( )</i> method in Pandas is powerful, but one restriction is that without any specific keyword arguments, it describes and returns descriptive statistics on columns that <strong>only</strong> contain numerical data (ints, floats).

# %%
df.describe(include="O")
# Out:
#                track_name currency   ver cont_rating prime_genre
# count                7197     7197  7197        7197        7197
# unique               7195        1  1546           4          23
# top     VR Roller Coaster      USD     1          4+       Games
# freq                    2     7197   322        4433        3862

# %% [markdown]
# ### Notice anything interesting?
#
# If you look carefully, the CURRENCY column has a 'count' value of 7000 but also has a 'unique' value of 1.
#
# This means that every value in the CURRENCY column <strong>is the same</strong>!
#
# Looking at the data shows that the value under observation is the type of currency of all data: "USD".
#
# This isn't that important to us, so we can make the executive judgment to <strong>drop that column</strong> to reduce the size of the data.

# %%
# NOTE: Running this multiple times will throw errors.
df = df.drop("currency", axis="columns")

# %%
df["size_Mb"] = df["size_bytes"].apply(lambda num: np.around(num / 1000000, decimals=2))
df.drop("size_bytes", axis="columns", inplace=True)

# %%
df.head()
# Out:
#           id                                         track_name currency  \
# 1  281656475                                    PAC-MAN Premium      USD
# 2  281796108                          Evernote - stay organized      USD
# 3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts      USD
# 4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...      USD
# 5  282935706                                              Bible      USD
#
#    price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 1   3.99             21292                26          4.0              4.5
# 2   0.00            161065                26          4.0              3.5
# 3   0.00            188583              2822          3.5              4.5
# 4   0.00            262241               649          4.0              4.5
# 5   0.00            985920              5320          4.5              5.0
#
#       ver cont_rating   prime_genre  sup_devices.num  ipadSc_urls.num  \
# ...

# %%
df.tail()
# Out:
#                id                                 track_name currency  price  \
# 11081  1187617475                                      Kubik      USD   0.00
# 11082  1187682390                          VR Roller-Coaster      USD   0.00
# 11087  1187779532      Bret Michaels Emojis + Lyric Keyboard      USD   1.99
# 11089  1187838770  VR Roller Coaster World - Virtual Reality      USD   0.00
# 11097  1188375727               Escape the Sweet Shop Series      USD   0.00
#
#        rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 11081               142                75          4.5              4.5
# 11082                30                30          4.5              4.5
# 11087                15                 0          4.5              0.0
# 11089                85                32          4.5              4.5
# 11097                 3                 3          5.0              5.0
#
# ...

# %% [markdown]
# ## Basic Visualizations
#
# Let's get to the fun part! We're going to rely primarily on SeaBorn visualizations to illustrate its authenticity and aptitude for beautiful and simple visualizations. Each of these can also be replicated through MatPlotLib, though it would take much longer.
#
# ### Let's explore the distribution of apps based on byte size.
#
# Remember that reformat we did to change 'size_bytes' data to 'size_Mb' data? That's going to come in handy, as we're going to generate a histogram of frequency occurrences (counts) based on general data byte size.

# %%
plt.subplots(figsize=(10, 8))

BINS = [0.00, 10.00, 20.00, 50.00, 100.00, 200.00, 500.00, 1000.00, 2000.00, np.inf]
LABELS = ["<10m", "10-20m", "20-50m", "50-100m", "100-200m", "200-500m", "500-1000m", "1-2G", ">2G"]

freqs = pd.cut(df["size_Mb"], BINS, include_lowest=True, labels=LABELS)
sns.barplot(y=freqs.value_counts().values, x=freqs.value_counts().index)

# %% [markdown]
# ### Looks great! Let's take a further look into priced vs. unpriced apps on the mobile store.
#
# We'll generate a doughnut plot using basic MatPlotLib to get a basic sense as to the distribution of paid vs. free apps on the app store.

# %%
BINS = [-np.inf, 0.00, np.inf]
LABELS = ["FREE", "PAID"]
colors = ['lightcoral', 'yellowgreen']

df["price_categories"] = pd.cut(df["price"], BINS, include_lowest=True, labels=LABELS)

fig, axs = plt.subplots(figsize=(10, 5))

price_df = df["price_categories"].value_counts()

plt.pie(price_df.values, labels=LABELS, colors=colors,
        autopct='%1.1f%%', shadow=True)
centre_circle = plt.Circle((0,0),0.75,color='black', fc='white',linewidth=1.25)

fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.axis('equal')
# Out:
# (-1.1057396083108322,
#  1.1002733599434824,
#  -1.1276675874208923,
#  1.1112839653444184)

# %% [markdown]
# Awesome! More paid apps than I expected, at least.
#
# ### Let's keep moving with this idea and check out the highest rated free and paid apps.

# %%
free_apps = df.loc[df["price_categories"] == "FREE"]
paid_apps = df.loc[df["price_categories"] == "PAID"]

free_apps_rated = free_apps.sort_values(by=["rating_count_tot"], ascending=False)
paid_apps_rated = paid_apps.sort_values(by=["rating_count_tot"], ascending=False)

# %%
sns.barplot(x=free_apps_rated["rating_count_tot"][:10], y=free_apps_rated["track_name"][:10])

# %% [markdown]
# Interesting. Personally, I'm shocked that Clash of Clans is more popular than Temple Run. Ridiculous!

# %%
sns.barplot(x=paid_apps_rated["rating_count_tot"][:10], y=paid_apps_rated["track_name"][:10])

# %% [markdown]
# Looks like as much as I like Minecraft, it clearly doesn't hold a sword up to Fruit Ninja Classic.
#
# ### By the way, what if we just want to know the highest rated apps of all time, regardless of price?

# %%
plt.subplots(figsize=(20, 20))

ratings = df.sort_values(by=["rating_count_tot"], ascending=False)

sns.barplot(x=ratings["rating_count_tot"][:30], y=ratings["track_name"][:30])

# %% [markdown]
# I don't think anyone's truly surprised that "Marky Mark" Zuckerberg commands the mobile app market.

# %% [markdown]
# ## <i>See Games With Us</i>
#
# Before we were Make School, we were <i>Make Games With Us</i>. So before we continue, let's take a look at our mobile game market!

# %%
genres = df["prime_genre"].value_counts()
genres.sort_values(ascending=False, inplace=True)

plt.subplots(figsize=(20, 10))
sns.barplot(x=genres.values, y=genres.index, order=genres.index, orient="h")

# %% [markdown]
# Great! Over 3000 of our dataset's apps are mobile games! This is good for us; generally in data science, the more data we have, the better.
#
# (Though like everything in data science, there are always exceptions!)

# %%
games = df.loc[df["prime_genre"] == "Games"]
games.head()
# Out:
#            id                 track_name currency  price  rating_count_tot  \
# 1   281656475            PAC-MAN Premium      USD   3.99             21292
# 6   283619399           Shanghai Mahjong      USD   0.99              8253
# 10  284736660                Ms. PAC-MAN      USD   3.99              7885
# 11  284791396  Solitaire by MobilityWare      USD   4.99             76720
# 12  284815117           SCRABBLE Premium      USD   7.99            105776
#
#     rating_count_ver  user_rating  user_rating_ver     ver cont_rating  \
# 1                 26          4.0              4.5   6.3.5          4+
# 6               5516          4.0              4.0     1.8          4+
# 10                40          4.0              4.0   4.0.4          4+
# 11              4017          4.5              4.5  4.10.1          4+
# 12               166          3.5              2.5  5.19.0          4+
#
#    prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic  size_Mb  \
# ...

# %% [markdown]
# By the way, one nice feature of Jupyter data representation with Pandas is seeing sliced data by index.
#
# Check the far left side of the DataFrame above. Notice anything?
#
# You may note that those bolded numbers aren't exactly in arithmetic incrementing order. Rather, they are <i>the entries from the original data that match our slicing criteria</i>!
#
# ### Let's explore price a little deeper by <strong>exploring the distribution of mobile games by price</strong>.

# %%
prices = (games["price"].value_counts()) / (games["price"].shape[0]) * 100
prices.sort_values(ascending=False, inplace=True)

plt.subplots(figsize=(20, 10))
ax = sns.barplot(y=prices.values, x=prices.index, order=prices.index)
ax.set(xlabel="USD", ylabel="percent (%)")
# Out:
# [Text(0,0.5,'percent (%)'), Text(0.5,0,'USD')]

# %% [markdown]
# As you may have suspected, most mobile games are free of charge and the majority of mobile games are under $4.
#
# Not too many popular mobile games out there that charge you more than a coffee!
#
# ### Speaking of price, let's close off our tutorial with some final visualizations looking at mobile game popularity.

# %%
free_games = games.loc[games["price_categories"] == "FREE"]
paid_games = games.loc[games["price_categories"] == "PAID"]

free_games_rated = free_games.sort_values(by=["rating_count_tot"], ascending=False)
paid_games_rated = paid_games.sort_values(by=["rating_count_tot"], ascending=False)

fig = plt.figure(figsize=(20, 10))
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

sns.barplot(x=free_games_rated["rating_count_tot"][:10], y=free_games_rated["track_name"][:10], ax=ax1)
sns.barplot(x=paid_games_rated["rating_count_tot"][:10], y=paid_games_rated["track_name"][:10], ax=ax2)

# %% [markdown]
# While this is fine and dandy, keep in mind that currently we are only looking at top rated apps in both categories by <i>total rating</i>.
#
# For mobile developers, it may also be important to look at top rated apps in both categories by <strong>current rating of the latest released version</strong>!
#
# Let's explore that.

# %%
free_games_rated_curr = free_games.sort_values(by=["rating_count_ver"], ascending=False)
paid_games_rated_curr = paid_games.sort_values(by=["rating_count_ver"], ascending=False)

fig = plt.figure(figsize=(20, 10))
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

sns.barplot(x=free_games_rated_curr["rating_count_ver"][:10], y=free_games_rated_curr["track_name"][:10], ax=ax1)
sns.barplot(x=paid_games_rated_curr["rating_count_ver"][:10], y=paid_games_rated_curr["track_name"][:10], ax=ax2)

# %% [markdown]
# How interesting that the data displayed in the top ten categorical apps by current rating are not at all the same as the top ten by total rating?
#
# Perhaps this is due to many of the most popular apps on the app store having many more releases.
#
# <i>How would you go about trying to visualize the number of releases each app has?</i>

# %% [markdown]
# ## Final Thoughts
#
# Data Science is a continuous, iterative, and complex process – often involving formulating and reformulating critical questions surrounding obscure bodies of data in order to derive an easy-to-communicate result.
#
# Think about some of the questions you ended up answering in this tutorial.
#
# - What's the <strong>average byte size</strong> of mobile apps?
# - How many apps are <strong>free vs. paid</strong>?
# - How many mobile apps are games and what is the general categorical distribution of <strong>apps by genre</strong>?
# - What are the <strong>most popular mobile games</strong> by total popular rating?
